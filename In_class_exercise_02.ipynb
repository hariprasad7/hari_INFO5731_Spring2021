# %% [markdown]
# <a href="https://colab.research.google.com/github/hariprasad7/hari_INFO5731_Spring2021/blob/main/In_class_exercise_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The second In-class-exercise (1/27/2021, 20 points in total)**

# %% [markdown]
# (1) Write a Python program to find the duplicate elements in a given array of integers. Return -1 If there are no such elements. (4 points)

# %%
import array as arr
l1=int(input("Enter the number of elements in the array: "))
a=arr.array('i',[])
for x in range(l1):
  txt="Enter element {} in the array " 
  v=int(input(txt.format(x+1)))
  a.append(v)
dup=[]
for i in range(l1):
  c=0
  for j in range(l1):
    if a[j] in dup:
      continue
    if a[i]==a[j]:
      c+=1
      if c>1:
        dup.append(a[i])
l2=len(dup)
if l2>0:
  txt="The duplicate elements in the array are: {}"
  print(txt.format(dup))
else:
  print("-1")
# Out:
# Enter the number of elements in the array: 4
# Enter element 1 in the array 1
# Enter element 2 in the array 2
# Enter element 3 in the array 3
# Enter element 4 in the array 4
# -1

# %% [markdown]
# (2) Write a Python program to select all the Sundays of a specified year. (4 points)

# %%
import datetime
yr=int(input("Enter year: "))
#To calculate first sunday of month
m=1
def fstsun(m):
  a=datetime.datetime(yr,m,1)
  s=int(a.strftime("%w"))
  if s==0:
    return 1
  else:
    return (1+(7-s))
d=fstsun(m)
#To display number of sundays in that particular year
while m<= 12:
  try:
    y=datetime.datetime(yr,m,d)
  except ValueError:
    m+=1
    if m<=12:
      d=fstsun(m)
  else:
    su=y.strftime("%x")
    print(su)
    d=d+7
# Out:
# Enter year: 2019
# 01/06/19
# 01/13/19
# 01/20/19
# 01/27/19
# 02/03/19
# 02/10/19
# 02/17/19
# 02/24/19
# 03/03/19
# 03/10/19
# 03/17/19
# 03/24/19
# 03/31/19
# 04/07/19
# 04/14/19
# 04/21/19
# 04/28/19
# 05/05/19
# 05/12/19
# 05/19/19
# 05/26/19
# 06/02/19
# 06/09/19
# 06/16/19
# 06/23/19
# 06/30/19
# 07/07/19
# 07/14/19
# 07/21/19
# 07/28/19
# 08/04/19
# 08/11/19
# 08/18/19
# 08/25/19
# 09/01/19
# 09/08/19
# 09/15/19
# 09/22/19
# 09/29/19
# 10/06/19
# 10/13/19
# 10/20/19
# 10/27/19
# 11/03/19
# 11/10/19
# 11/17/19
# 11/24/19
# 12/01/19
# 12/08/19
# 12/15/19
# 12/22/19
# 12/29/19

# %% [markdown]
# (3) Python files reading and writing. Download the “[exercise_02_data _collection.zip](https://github.com/unt-iialab/info5731_spring2021/blob/main/class_exercises/exercise_02_data_collection.zip)” to your local and un-zip it.
#
# *   Write a program to read all the txt files and save the sentences in all the files into one csv file with two columns, the first column is sentence id (txt file name+sentence line number), the second column is the sentence text content. (4 points)
# *   Remove all the punctuations from the sentences, save the processed sentences into a new column in the same csv file. (4 points)
# *   Ask the user to enter a word, return all the sentences that include this word, three kinds of information should be returned: sentence id, sentence text content, the count that user input word appear in the sentence. (4 points)

# %%
import csv
import os
import zipfile
import re
with zipfile.ZipFile('exercise_02_data_collection.zip') as zf:
    List1 = []
    for fname1 in zf.namelist():
        if not os.path.isdir(fname1):
            with zf.open(fname1) as f:
                c = 0
                #fl = f.read().split('.')
                for line in f:
                  (file, ext) = os.path.splitext(fname1)
                  line = line.decode("utf-8")
                  c = c + 1
                  c1 = file[file.index('/')+1:] + str(c)
                  c2 = line
                  list2 = []
                  list2.append(c1)
                  list2.append(c2)
                  column3 = re.sub(r'[^\w\s]', '', c2) 
                  list2.append(column3)
                  List1.append(list2)
                  #print(mylist)
    outfile=open('result.csv','w')
    wr = csv.writer(outfile, quoting=csv.QUOTE_ALL)
    for i in List1:
      wr.writerow(i)

    word = input("enter a word to search from the sentences:")
    c = 1
    for i in List1:
      for lin in i[2:3]:
        for li in lin.split(" "):
          if word == li:
            print("matched sentence = ",lin, " count = ",len(re.findall(r'\w+', lin)))
            c = c + 1
# Out:
# enter a word to search from the sentences:you
# matched sentence =  This drug cant be good for you if it brought my period on when ive only just finished my last cycle 10 dyas prior to taking the drug
#   count =  28
# matched sentence =  Hadnt realised it was related until I read this but I get the hunger pangs too Im assuming this is the acids and gas in your stomach constantly churning over that make you feel like youre hungry
#   count =  37
# matched sentence =  Every time I stand up I have to hold onto something for fear of falling over I feel sick and light headed and I get those waves of nausea where you suddenly feel all clammy
#   count =  35
# matched sentence =  Truly wish you could have same results as i have
#   count =  10
# matched sentence =  Why they dont tell you about them
#   count =  7
# ...

# %% [markdown]
# (4) Install packages nltk, numpy, scipy, pandas, and sklearn on Google Colab. Write a program to test whether they are installed successfully. (3 points for extra)

# %%
# !pip install nltk
# !pip install numpy
# !pip install scipy
# !pip install pandas
# !pip install sklearn
# !pip list
# Out:
# ...
# Package                       Version
# ----------------------------- ---------------
# absl-py                       0.10.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# asgiref                       3.3.1
# astor                         0.8.1
# astropy                       4.1
# astunparse                    1.6.3
# async-generator               1.10
# atari-py                      0.2.6
# atomicwrites                  1.4.0
# attrs                         20.3.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        3.2.3
# blis                          0.4.1
# bokeh                         2.1.1
# Bottleneck                    1.3.2
# branca                        0.4.2
# ...
